# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from spopt.region import MaxPHeuristic as MaxP
from libpysal.weights import Queen
import matplotlib.pyplot as plt

# Load the data from the Excel file
file_path = 'us_country.xlsx'
df = pd.read_excel(file_path, usecols=['Zip', 'lat', 'long', 'population'])

# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(df['long'], df['lat'])]
gdf = gpd.GeoDataFrame(df, geometry=geometry)

# Create a spatial weights matrix
w = Queen.from_dataframe(gdf)

# Define the minimum population threshold for each region
threshold = 40000000

# Perform Max-P Regionalization
model = MaxP(gdf, w, 'population',threshold_name='population', threshold=threshold)
gdf['region'] = model.solve()

# Plot the regions
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax, color='white', edgecolor='black')
gdf.assign(region=gdf['region']).plot(column='region', ax=ax, legend=True, cmap='tab20')
plt.title('US Zip Code Regions with Comparable Population')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# /tmp/ipykernel_58/2696329498.py:17: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w = Queen.from_dataframe(gdf)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 17
#      14 gdf = gpd.GeoDataFrame(df, geometry=geometry)
#      16 # Create a spatial weights matrix
# ---> 17 w = Queen.from_dataframe(gdf)
#      19 # Define the minimum population threshold for each region
#      20 threshold = 40000000
#
# File /opt/conda/lib/python3.9/site-packages/libpysal/weights/contiguity.py:528, in Queen.from_dataframe(cls, df, geom_col, idVariable, ids, id_order, use_index, **kwargs)
#     525 if id_order is None:
#     526     id_order = ids
# --> 528 return cls.from_iterable(
#     529     df[geom_col].tolist(), ids=ids, id_order=id_order, **kwargs
#     530 )
#
# File /opt/conda/lib/python3.9/site-packages/libpysal/weights/contiguity.py:416, in Queen.from_iterable(cls, iterable, sparse, **kwargs)
#     399 """
#     400 Construct a weights object from a collection of arbitrary polygons. This
#     401 will cast the polygons to PySAL polygons, then build the W.
#    (...)
#     413 :class:`libpysal.weights.contiguiyt.Queen`
#     414 """
#     415 new_iterable = iter(iterable)
# --> 416 w = cls(new_iterable, **kwargs)
#     417 if sparse:
#     418     w = WSP.from_W(w)
#
# File /opt/conda/lib/python3.9/site-packages/libpysal/weights/contiguity.py:335, in Queen.__init__(self, polygons, **kw)
#     333 first_shape = next(iter(backup))
#     334 if isinstance(first_shape, point_type):
# --> 335     polygons, vertices = voronoi_frames(get_points_array(polygons))
#     336     polygons = list(polygons.geometry)
#     337 neighbors, ids = _build(polygons, criterion=criterion, ids=ids)
#
# File /opt/conda/lib/python3.9/site-packages/libpysal/cg/voronoi.py:245, in voronoi_frames(points, radius, clip)
#     195 def voronoi_frames(points, radius=None, clip="extent"):
#     196     """Composite helper to return Voronoi regions and
#     197     generator points as individual dataframes.
#     198
#    (...)
#     242
#     243     """
# --> 245     regions, vertices = voronoi(points, radius=radius)
#     246     regions, vertices = as_dataframes(regions, vertices, points)
#     247     if clip:
#
# File /opt/conda/lib/python3.9/site-packages/libpysal/cg/voronoi.py:57, in voronoi(points, radius)
#      16 def voronoi(points, radius=None):
#      17     """Determine finite Voronoi diagram for a 2-d point set.
#      18     See also ``voronoi_regions()``.
#      19
#    (...)
#      54
#      55     """
# ---> 57     vor = voronoi_regions(Voronoi(points), radius=radius)
#      59     return vor
#
# File /opt/conda/lib/python3.9/site-packages/libpysal/cg/voronoi.py:99, in voronoi_regions(vor, radius)
#      96     new_regions.append(vertices)
#      97     continue
# ---> 99 ridges = all_ridges[p1]
#     100 new_region = [v for v in vertices if v >= 0]
#     102 for p2, v1, v2 in ridges:
#
# KeyError: 142

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl (250kB)
#      |████████████████████████████████| 256kB 10.7MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install pandas
# !pip install geopandas
# !pip install shapely 
# !pip install spopt
# !pip install libpysal
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4; python_version < "3.11" in /opt/conda/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/c4/64/7d344cfcef5efddf9cf32f59af7f855828e9d74b5f862eddf5bfd9f25323/geopandas-1.0.1-py3-none-any.whl (323kB)
#      |████████████████████████████████| 327kB 8.7MB/s eta 0:00:01
# Collecting shapely>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/a5/b2/6a4589439880244f86c1d3061efd91faf8ec21e646df18730810b6d59481/shapely-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 38.0MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/lib/python3.9/site-packages (from geopandas) (2.2.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from geopandas) (24.1)
# Collecting pyogrio>=0.7.2
#   Downloading https://files.pythonhosted.org/packages/20/7a/56ef1f49388244b5d9e4f22db58745fd329f441f87af71fce0bbd6ddd894/pyogrio-0.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7MB)
#      |████████████████████████████████| 23.7MB 92.9MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.9/site-packages (from geopandas) (1.26.4)
# Collecting pyproj>=3.3.0
#   Downloading https://files.pythonhosted.org/packages/97/0a/b1525be9680369cc06dd288e12c59d24d5798b4afcdcf1b0915836e1caa6/pyproj-3.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3MB)
#      |████████████████████████████████| 8.3MB 101.7MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from pyogrio>=0.7.2->geopandas) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Installing collected packages: shapely, pyogrio, pyproj, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.6.1 shapely-2.0.6
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: shapely in /opt/conda/lib/python3.9/site-packages (2.0.6)
# Requirement already satisfied: numpy<3,>=1.14 in /opt/conda/lib/python3.9/site-packages (from shapely) (1.26.4)
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting spopt
#   Downloading https://files.pythonhosted.org/packages/22/37/7cbae98df9b60bc5fc276a531d7eef95e950f5902cf339f8c0be16291e20/spopt-0.5.0-py3-none-any.whl (112kB)
#      |████████████████████████████████| 122kB 10.7MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.9/site-packages (from spopt) (1.26.4)
# Collecting spaghetti
#   Downloading https://files.pythonhosted.org/packages/d0/c7/2bc5b1dbd132b0ae19d2bd231b679969503d4de496ef17dadd30a4218740/spaghetti-1.7.4-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 14.7MB/s eta 0:00:01
# Collecting scikit-learn>=0.22
#   Downloading https://files.pythonhosted.org/packages/c3/57/1bc8878528ebd28ba4e84001593ffc62d861d49d3ef3a9ac75a45acb04a1/scikit_learn-1.6.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5MB)
#      |████████████████████████████████| 13.5MB 132.4MB/s eta 0:00:01
# Requirement already satisfied: geopandas>=0.10.0 in /opt/conda/lib/python3.9/site-packages (from spopt) (1.0.1)
# Collecting pulp
#   Downloading https://files.pythonhosted.org/packages/64/10/704c18b5960b3f9b10efcc859e11881ad90f1e44008e181d2b10cd305a63/PuLP-2.9.0-py3-none-any.whl (17.7MB)
#      |████████████████████████████████| 17.7MB 55.6MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.27.0 in /opt/conda/lib/python3.9/site-packages (from spopt) (4.66.4)
# Collecting scipy>=1.3.2
#   Downloading https://files.pythonhosted.org/packages/35/f5/d0ad1a96f80962ba65e2ce1de6a1e59edecd1f0a7b55990ed208848012e0/scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6MB)
#      |████████████████████████████████| 38.6MB 77.4MB/s eta 0:00:01
# Collecting networkx
#   Downloading https://files.pythonhosted.org/packages/d5/f0/8fbc882ca80cf077f1b246c0e3c3465f7f415439bdea6b899f6b19f61f70/networkx-3.2.1-py3-none-any.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 81.1MB/s eta 0:00:01
# Collecting libpysal
#   Downloading https://files.pythonhosted.org/packages/1e/54/1d6caca55ed3d8d57a544853dd72a0514b464dbd787f28883bec2123ae29/libpysal-4.8.1-py3-none-any.whl (2.8MB)
#      |████████████████████████████████| 2.8MB 98.1MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0.5 in /opt/conda/lib/python3.9/site-packages (from spopt) (2.2.0)
# Collecting rtree
#   Downloading https://files.pythonhosted.org/packages/70/db/6c8bc20061572c33766ade296071d0127e7365d4d3ff54a6c2c075de637b/Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (543kB)
#      |████████████████████████████████| 552kB 105.7MB/s eta 0:00:01
# Collecting esda
#   Downloading https://files.pythonhosted.org/packages/ea/e1/6000a61d9a964dbb592db8271232693ef2e341d088c7bdf9393a9a34b658/esda-2.5.1-py3-none-any.whl (132kB)
#      |████████████████████████████████| 133kB 119.7MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl
# Collecting joblib>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl (301kB)
#      |████████████████████████████████| 307kB 126.0MB/s eta 0:00:01
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from geopandas>=0.10.0->spopt) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.9/site-packages (from geopandas>=0.10.0->spopt) (3.6.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.9/site-packages (from geopandas>=0.10.0->spopt) (0.10.0)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from geopandas>=0.10.0->spopt) (2.0.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from libpysal->spopt) (2.32.3)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.9/site-packages (from libpysal->spopt) (4.12.3)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from libpysal->spopt) (4.2.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.0.5->spopt) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.0.5->spopt) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.0.5->spopt) (2024.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from pyproj>=3.3.0->geopandas>=0.10.0->spopt) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->libpysal->spopt) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->libpysal->spopt) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->libpysal->spopt) (3.7)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.9/site-packages (from beautifulsoup4>=4.10->libpysal->spopt) (2.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->spopt) (1.16.0)
# Installing collected packages: rtree, scipy, libpysal, threadpoolctl, joblib, scikit-learn, esda, spaghetti, pulp, networkx, spopt
# Successfully installed esda-2.5.1 joblib-1.4.2 libpysal-4.8.1 networkx-3.2.1 pulp-2.9.0 rtree-1.3.0 scikit-learn-1.6.0 scipy-1.13.1 spaghetti-1.7.4 spopt-0.5.0 threadpoolctl-3.5.0
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: libpysal in /opt/conda/lib/python3.9/site-packages (4.8.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from libpysal) (24.1)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.9/site-packages (from libpysal) (2.2.0)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.9/site-packages (from libpysal) (4.12.3)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from libpysal) (4.2.2)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.9/site-packages (from libpysal) (1.13.1)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.9/site-packages (from libpysal) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from libpysal) (2.32.3)
# Requirement already satisfied: shapely>=2 in /opt/conda/lib/python3.9/site-packages (from libpysal) (2.0.6)
# Requirement already satisfied: geopandas>=0.9 in /opt/conda/lib/python3.9/site-packages (from libpysal) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->libpysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->libpysal) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.4->libpysal) (2024.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.9/site-packages (from beautifulsoup4>=4.10->libpysal) (2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->libpysal) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->libpysal) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->libpysal) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->libpysal) (3.3.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.9/site-packages (from geopandas>=0.9->libpysal) (3.6.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.9/site-packages (from geopandas>=0.9->libpysal) (0.10.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->libpysal) (1.16.0)
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/5d/a7/bb01188fb4013d34d274caf44a2f8091255b0497438e8b6c0a7c1710c692/matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3MB)
#      |████████████████████████████████| 8.3MB 9.6MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading https://files.pythonhosted.org/packages/6b/77/9893aa413e7d839e292685bae0749a319eacba9470c85253529d35248075/fonttools-4.55.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6MB)
#      |████████████████████████████████| 4.6MB 106.6MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0; python_version < "3.10"
#   Downloading https://files.pythonhosted.org/packages/a4/ed/1f1afb2e9e7f38a545d628f864d562a5ae64fe6f7a10e28ffb9b185b4e89/importlib_resources-6.5.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Collecting contourpy>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/05/11/57335544a3027e9b96a05948c32e566328e3a2f84b7b99a325b7a06d2b06/contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321kB)
#      |████████████████████████████████| 327kB 106.8MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (24.1)
# Collecting pyparsing>=2.3.1
#   Downloading https://files.pythonhosted.org/packages/1c/a7/c8a2d361bf89c0d9577c934ebb7421b25dc84bf3a8e3ac0a40aed9acc547/pyparsing-3.2.1-py3-none-any.whl (107kB)
#      |████████████████████████████████| 112kB 132.6MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Collecting pillow>=8
#   Downloading https://files.pythonhosted.org/packages/f6/46/0bd0ca03d9d1164a7fa33d285ef6d1c438e963d0c8770e4c5b3737ef5abe/pillow-11.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4MB)
#      |████████████████████████████████| 4.4MB 73.7MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl
# Collecting kiwisolver>=1.3.1
#   Downloading https://files.pythonhosted.org/packages/21/b1/40655f6c3fa11ce740e8a964fa8e4c0479c87d6a7944b95af799c7a55dfe/kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 74.2MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /opt/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: fonttools, importlib-resources, contourpy, pyparsing, pillow, cycler, kiwisolver, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.55.3 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.1.0 pyparsing-3.2.1
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
